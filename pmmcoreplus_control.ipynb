# %%
from pymmcore_plus import CMMCorePlus
from useq import MDAEvent

# Create the core instance.
mmc = CMMCorePlus.instance()  
mmc.loadSystemConfiguration()  

# Create a super-simple sequence, with one event
mda_sequence = [MDAEvent()] 
mmc.getLoadedDevices()
# Run it!
#mmc.run_mda(mda_sequence)
# Out:
# ('DHub',
#  'Camera',
#  'Dichroic',
#  'Emission',
#  'Excitation',
#  'Objective',
#  'Z',
#  'Path',
#  'XY',
#  'White Light Shutter',
#  'Autofocus',
#  'LED',
#  'LED Shutter',
#  'Core')

# %%
mmc.loadSystemConfiguration("C:\\MATLAB Microscope\AmoghMMConfig.cfg")

Devices = mmc.getLoadedDevices();
Devices_list = ()
for i in range(len(Devices)):
    Devices_list(i,1) = char(Devices.get(i-1)); 

mikroscope.camera = mmc.getCameraDevice()
mikroscope.DIAshutter = mmc.getShutterDevice()
mikroscope.focus= mmc.getFocusDevice()
mikroscope.stage = mmc.getXYStageDevice()
mikroscope.PFS = mmc.getAutoFocusDevice()
mikroscope.EPIshutter = java.lang.String('TIEpiShutter')
mikroscope.DIAlamp = java.lang.String('TIDiaLamp')
mikroscope.scope = java.lang.String('TIScope')
mikroscope.zoom = java.lang.String('TINosePiece')
mikroscope.filter = java.lang.String('TIFilterBlock1')
mikroscope.lightpath = java.lang.String('TILightPath')
mikroscope.PFS_offset = java.lang.String('TIPFSOffset')
mikroscope.core = java.lang.String('Core')
# Out:
#   Cell In[7], line 6
#     Devices_list(i,1) = char(Devices.get(i-1));
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?
